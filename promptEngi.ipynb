# %%
import os
os.environ["OPENAI_API_KEY"]= "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"

# %%
from langchain import PromptTemplate
demo_template = '''i want you to act as a acting financial advisor for people . In and easy wau , explain the basics of{financial_concept}.'''

prompt = PromptTemplate(
    input_variables = ['financial_concept'],
    template = demo_template
    )

prompt.format(financial_concept = 'income tax')
# Out:
# 'i want you to act as a acting financial advisor for people . In and easy wau , explain the basics ofincome tax.'

# %%
from langchain.llms import OpenAI
from langchain.chains import LLMChain

llm = OpenAI(temperature = 0.7)
chain1 = LLMChain(llm = llm , prompt = prompt)

# %%
chain1.run('income tax')
# Out:
# /var/folders/z3/rlq7cx6d5ml4k7yyp1gr50g80000gn/T/ipykernel_61706/2008276715.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain1.run('income tax')
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 chain1.run('income tax')
#
# File ~/coding/langchain/myenv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File ~/coding/langchain/myenv/lib/python3.9/site-packages/langchain/chains/base.py:603, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     601     if len(args) != 1:
# ...

# %%
#language translation

from langchain import PromptTemplate
template = '''in an wassy way translate the following sentence {sentence} into {target_translation}'''

language_prompt = PromptTemplate(
    input_varibles=["sentence", 'target_langugage'],
    template = template,
)

language_prompt.format(sentence="how are you", target_language='hindi')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 11
#       4 template = '''in an wassy way translate the following sentence {sentence} into {target_translation}'''
#       6 language_prompt = PromptTemplate(
#       7     input_varibles=["sentence", 'target_langugage'],
#       8     template = template,
#       9 )
# ---> 11 language_prompt.format(sentence="how are you", target_language='hindi')
#
# File ~/coding/langchain/myenv/lib/python3.9/site-packages/langchain_core/prompts/prompt.py:186, in PromptTemplate.format(self, **kwargs)
#     177 """Format the prompt with the inputs.
#     178
#     179 Args:
#    (...)
#     183     A formatted string.
#     184 """
#     185 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 186 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# ...

# %%
chain2 = LLMChain(llm = llm, prompt = prompt)

chain2({'sentence' : "hello how are you ",'target_language': 'French'})
